# %% [markdown]
# HW #3: Exercise 5.5

# %%
class particle(object):  ## We recycle our 1D particle object
    
    def __init__(self, mass=1., x=0., v=0.):
        self.mass = mass
        self.f = 0
        self.x= x
        self.v = v
        
    def move(self, dt):
        # Euler-Cromer
        self.v = self.v + self.f/self.mass*dt
        self.x = self.x + self.v*dt
        
class CoupledSystem(object):

    def __init__(self, N, k, kc, dt): 
        self.N = N
        self.dt = dt
        self.k = k
        self.kc = kc
        self.particles = [particle()]
        for i in range(1,N):
            self.particles.append(particle()) # we create a list of N particles

    def evolve(self):        
        # Compute the interaction forces with the other particles
        for i in range(self.N-1):
            self.particles[i].f = self.kc*(self.particles[i+1].x + self.particles[i-1].x - 2*self.particles[i].x)
        self.particles[0].f = self.kc*(self.particles[1].x - self.particles[0].x) - self.k*self.particles[0].x
        self.particles[N-1].f = self.kc*(self.particles[N-2].x - self.particles[N-1].x) - self.k*self.particles[N-1].x

        for p in self.particles:
            p.move(dt)
            
    def energy(self):
        # Challenge
        return (ke,pe)

# %%
# %matplotlib inline
import numpy as np
from matplotlib import pyplot

N = 3
k = 1.0
kc = 0.2
dt = 0.01
tmax = 400
nsteps = int(tmax/dt)

S = CoupledSystem(N, k, kc, dt)
S.particles[0].x = -0.1
S.particles[1].x = 0.2
S.particles[2].x = 0.7

t = np.linspace(0.,tmax,nsteps)
x = np.zeros(shape=(N,nsteps))

for i in range(nsteps):
    for n in range(S.N):
        x[n,i] = S.particles[n].x
    S.evolve()

pyplot.plot(t, x[0,], color='green', ls='-', lw=1)
pyplot.plot(t, x[1,], color='red', ls='-', lw=1)
pyplot.plot(t, x[2,], color='blue', ls='-', lw=1)

pyplot.xlabel('time (s)')
pyplot.ylabel('x (m)');
pyplot.title('Part 1 Plot: Position vs. Time')

# %%
w = np.fft.rfftfreq(nsteps,dt)
u0 = np.fft.rfft(x[0,])
u1 = np.fft.rfft(x[1,])
u2 = np.fft.rfft(x[2,])

pyplot.plot(w, abs(u0), color='green', ls='-', lw=1)
pyplot.plot(w, abs(u1), color='red', ls='-', lw=1)
pyplot.plot(w, abs(u2), color='blue', ls='-', lw=1)
pyplot.xlim(0,.25);

pyplot.xlabel('Frequency (hertz)')
pyplot.ylabel('Strength (units)');
pyplot.title('Part 1 Plot: Frequency Spectrum')

# %% [markdown]
# Part 1 Answer:
#
# The time dependence of the motion of the particles can be explain with  few words: they are a result of three different modes factoring in. There are three different particles and two different spring constants ($k$ and $k_c$), and each particle generates one mode (or frequency). The behavior of the particles is a summation of the three modes. The middle particle, particle 1, is attached to only $k_c$ springs, which means its behavior will mostly be influenced by the $k_c$ mode. On the other hand, particles 0 and 2 will be mostly influenced by the $k$ mode.
#
# The relative strength of the two modes is determined by the initial conditions. If the initial starting position for the particles 0 and 2 is very large realtive to 1, then the $k$ modes will dominate. On the other hand, if the initial positions as small compared to particle 1, then the $k_c$ modes will dominate.
#
# We know which modes will dominate by the frequency spectrum. It can be seen that the red plot has a more even distribution of $k$ and $k_c$ modes compared to blue and green. This makes sense because red corresponds to particle 1, which only has $k_c$ springs attached. Particles 0 and 2 have both $k$ and $k_c$ springs, so they will have more energy in the k mode.
#
# Blue has the most energy because it had the largest initial displacement. It was given the most initial energy. The energy was mostly in the $k$ spring. This is why the $k$ mode peak is the highest.
#
# Note the two blue peaks very close to each other. This detail can be lost when the length of time is not high enough.
#
# #--
#
# The three normal mode frequencies are ~0.09 hertz, and two frequencies around 1.7 hertz. These were found by looking at the two tallest peaks in graph above. The values above can also be found by finding the Lagragian, solving the equations of motion, putting them in matrix form, and then finding the eigenvalues. I used Matlab to find the eigenvalues. These gave me angular freqeuency values of 0.310, 1.2 and 1.29. I then converted those values to frequency. The below equations is an expression how the spring constants relate to frequency: $$f = (\frac{k}{m})^{\frac{1}{2}}\frac{1}{2\pi}$$
#
# We know $k=1.$, $k_c = 0.2$, and $m = 1.$.
#
# The plot shows that the $k$ mode has the most energy. Additionally, the green plot of particle 0 cannot be seen because the blue plot is covering it up. This is because the initial conditions and the spring constant of particles 0 and 2 were identical, so they will have identical responses.
#
# The peak around 1.7 hertz has two peaks hidden inside of it.
#
# I found the three normal modes of the system by finding the equations of motion and having matlab solve for the eigenvectors. They are: $$f_1 = 0.089hertz$$ $$eigenvector1 = (0.214, 0.953, 0.214)$$ $$ $$ $$f_2 = 0.174hertz$$ $$eigenvector2 = (-0.707, 0., 0.707)$$ $$ $$ $$f_3 = 0.181hertz$$ $$eigenvector3 = (-0.674, 0.302, 0.674)$$
#
# #----------------------------------------------------------------------
#
# Question/Part 2 Below:

# %%
# %matplotlib inline
import numpy as np
from matplotlib import pyplot

N = 3
k = 1.0
kc = 0.2
dt = 0.01
tmax = 400
nsteps = int(tmax/dt)

S = CoupledSystem(N, k, kc, dt)
S.particles[0].x = 0.5
S.particles[1].x = 0.
S.particles[2].x = -0.5

t = np.linspace(0.,tmax,nsteps)
x = np.zeros(shape=(N,nsteps))

for i in range(nsteps):
    for n in range(S.N):
        x[n,i] = S.particles[n].x
    S.evolve()

#x1 = np.zeros(shape=(N,nsteps))
#x2 = np.zeros(shape=(N,nsteps))
x3 = np.zeros(shape=(N,nsteps))

x3 = x

# %%
pyplot.plot(t, x1[0,], color='green', ls='-', lw=1)
pyplot.plot(t, x1[1,], color='red', ls='-', lw=1)
pyplot.plot(t, x1[2,], color='blue', ls='-', lw=1)

pyplot.xlabel('time (s)')
pyplot.ylabel('x (m)');
pyplot.title('Part 2 Plot 1: Position vs. Time u1=u2=u3=0.5')

# %%
w = np.fft.rfftfreq(nsteps,dt)
u0 = np.fft.rfft(x1[0,])
u1 = np.fft.rfft(x1[1,])
u2 = np.fft.rfft(x1[2,])

pyplot.plot(w, abs(u0), color='green', ls='-', lw=1)
pyplot.plot(w, abs(u1), color='red', ls='-', lw=1)
pyplot.plot(w, abs(u2), color='blue', ls='-', lw=1)
pyplot.xlim(0,.20);

pyplot.xlabel('Frequency (hertz)')
pyplot.ylabel('Strength (units)');
pyplot.title('Part 2 Plot1: Frequency Spectrum u1=u2=u3=0.5')

# %% [markdown]
# Part 2 Plot 1 Answer: The three normal mode frequencies are ~0.09 hertz, and two frequencies around 1.7 hertz. These were found by looking at the two tallest peaks in graph above. The values above can also be found by finding the Lagragian, solving the equations of motion, putting them in matrix form, and then finding the eigenvalues. I used Matlab to find the eigenvalues. These gave me angular freqeuency values of 0.310, 1.2 and 1.29. I then converted those values to frequency. The below equations is an expression how the spring constants relate to frequency: $$f = (\frac{k}{m})^{\frac{1}{2}}\frac{1}{2\pi}$$
#
# We know $k=1.$, $k_c = 0.2$, and $m = 1.$.
#
# The plot shows that the $k$ mode has the most energy. Additionally, the green plot of particle 0 cannot be seen because the blue plot is covering it up. This is because the initial conditions and the spring constant of particles 0 and 2 were identical, so they will have identical responses.
#
# The peak around 1.7 hertz has two peaks hidden inside of it.
#
# I found the three normal modes of the system by finding the equations of motion and having matlab solve for the eigenvectors. They are: $$f_1 = 0.089hertz$$ $$eigenvector1 = (0.214, 0.953, 0.214)$$ $$ $$ $$f_2 = 0.174hertz$$ $$eigenvector2 = (-0.707, 0., 0.707)$$ $$ $$ $$f_3 = 0.181hertz$$ $$eigenvector3 = (-0.674, 0.302, 0.674)$$
#
# #-----------------------------------------

# %%
pyplot.plot(t, x2[0,], color='green', ls='-', lw=3)
pyplot.plot(t, x2[1,], color='red', ls='-', lw=3)
pyplot.plot(t, x2[2,], color='blue', ls='-', lw=3)

pyplot.xlabel('time (s)')
pyplot.ylabel('x (m)');
pyplot.title('Part 2 Plot 2: Position vs. Time u1=u3=0.5,u2=-0.5')

# %%
w = np.fft.rfftfreq(nsteps,dt)
u0 = np.fft.rfft(x2[0,])
u1 = np.fft.rfft(x2[1,])
u2 = np.fft.rfft(x2[2,])

pyplot.plot(w, abs(u0), color='green', ls='-', lw=1)
pyplot.plot(w, abs(u1), color='red', ls='-', lw=1)
pyplot.plot(w, abs(u2), color='blue', ls='-', lw=1)
pyplot.xlim(0,.2);

pyplot.xlabel('Frequency (hertz)')
pyplot.ylabel('Strength (units)');
pyplot.title('Part 2 Plot 2: Frequency Spectrum u1=u3=0.5,u2=-0.5')

# %% [markdown]
# Part 2 Plot 2 Answer: The three normal mode frequencies are ~0.09 hertz, and two frequencies around 1.7 hertz.  These were found by looking at the two tallest peaks in graph above. One can also solve for them using the methods described above.
#
# The plot shows that the $k_c$ mode has the most energy. Additionally, the green plot of particle 0 cannot be seen because the blue plot is covering it up. This is because the initial conditions and the spring constant of particles 0 and 2 were identical, so they will have identical responses.
#
# #----------------------------------------

# %%
pyplot.plot(t, x3[0,], color='green', ls='-', lw=3)
pyplot.plot(t, x3[1,], color='red', ls='-', lw=3)
pyplot.plot(t, x3[2,], color='blue', ls='-', lw=3)

pyplot.xlabel('time (s)')
pyplot.ylabel('x (m)');
pyplot.title('Part 2 Plot 3: Position vs. Time u1=0.5,u2=0,u3=-0.5')

# %%
w = np.fft.rfftfreq(nsteps,dt)
u0 = np.fft.rfft(x3[0,])
u1 = np.fft.rfft(x3[1,])
u2 = np.fft.rfft(x3[2,])

pyplot.plot(w, abs(u0), color='green', ls='-', lw=1)
pyplot.plot(w, abs(u1), color='red', ls='-', lw=1)
pyplot.plot(w, abs(u2), color='blue', ls='-', lw=1)
pyplot.xlim(0,.2);

pyplot.xlabel('Frequency (hertz)')
pyplot.ylabel('Strength (units)');
pyplot.title('Part 2 Plot 3: Frequency Spectrum u1=0.5,u2=0,u3=-0.5')

# %% [markdown]
# Part 2 Plot 3 Answer: The three normal mode frequencies are ~0.09 hertz, and two frequencies around 1.7 hertz. These were found by looking at the two tallest peaks in graph above. One can also solve for them using the method described above.
#
# However, the $k$ normal mode cannot be seen. This is because particle 1 was not given any initial energy, and the starting positions of particles 0 and 2 were identical, with the exception of their signs. This caused the two forces exerted on particle 1 to cancel out, so particle 1 felt no net force. As a result, almost all the energy was stored in the $k_c$ springs.
#
# The green plot of particle 0 cannot be seen because the blue plot is covering it up. This is because the magnitude of the initial conditions and the spring constants of particles 0 and 2 were identical, so they will have identical responses.
#
# #-----------------------------------------
# #-----------------------------------------

# %%
class particle(object):  ## We recycle our 1D particle object
    
    def __init__(self, mass=1., x=0., v=0.):
        self.mass = mass
        self.f = 0
        self.x= x
        self.v = v
        
    def move(self, dt):
        # Euler-Cromer
        self.v = self.v + self.f/self.mass*dt
        self.x = self.x + self.v*dt
        
class CoupledSystem(object):

    def __init__(self, N, k, kc, dt): 
        self.N = N
        self.dt = dt
        self.k = k
        self.kc = kc
        #self.j = j
        self.particles = [particle()]
        for i in range(1,N):
            self.particles.append(particle()) # we create a list of N particles

    def evolve(self, j):        
        # Compute the interaction forces with the other particles
        for i in range(self.N-1):
            self.particles[i].f = self.kc*(self.particles[i+1].x + self.particles[i-1].x - 2*self.particles[i].x)
        
        #   Added driving force to the line below (u1). Driving Force = 0.5cos(2*pi*0.5*time) where the frequency is 0.5
        self.particles[0].f = self.kc*(self.particles[1].x - self.particles[0].x) - self.k*self.particles[0].x + .5*math.cos(2*math.pi*.5*dt*j)
        self.particles[N-1].f = self.kc*(self.particles[N-2].x - self.particles[N-1].x) - self.k*self.particles[N-1].x

        for p in self.particles:
            p.move(dt)
            
    def energy(self):
        # Challenge
        return (ke,pe)

# %%
# %matplotlib inline
import numpy as np
import math
from matplotlib import pyplot

N = 3
k = 1.0
kc = 0.2
dt = 0.01
tmax = 40
nsteps = int(tmax/dt)

S = CoupledSystem(N, k, kc, dt)
S.particles[0].x = -0.5
S.particles[1].x = 0.
S.particles[2].x = 0.5

t = np.linspace(0.,tmax,nsteps)
x = np.zeros(shape=(N,nsteps))

for i in range(nsteps):
    for n in range(S.N):
        x[n,i] = S.particles[n].x
    S.evolve(i)

# %%
pyplot.plot(t, x[0,], color='green', ls='-', lw=3)
pyplot.plot(t, x[1,], color='red', ls='-', lw=3)
pyplot.plot(t, x[2,], color='blue', ls='-', lw=3)

pyplot.xlabel('time (s)')
pyplot.ylabel('x (m)');
pyplot.title('Part 3: Position vs. Time u1=0.5,u2=0,u3=-0.5')

# %%
w = np.fft.rfftfreq(nsteps,dt)
u0 = np.fft.rfft(x[0,])
u1 = np.fft.rfft(x[1,])
u2 = np.fft.rfft(x[2,])

pyplot.plot(w, abs(u0), color='green', ls='-', lw=1)
pyplot.plot(w, abs(u1), color='red', ls='-', lw=1)
pyplot.plot(w, abs(u2), color='blue', ls='-', lw=1)
pyplot.xlim(0,1);

pyplot.xlabel('Frequency (hertz)')
pyplot.ylabel('Strength (units)');
pyplot.title('Part 3: Frequency Spectrum u1=0.5,u2=0,u3=-0.5')

# %% [markdown]
# Part 3 Exercise 5.5 Answer:
#
# For part 3 I chose to use the initial conditions u1=.5, u2=0, and u3=.5. I then added a cosine forcing function with a frequency = 0.5.
#
# This can be seen in the above code. In part 2 these initial conditions produced only one visible peak at 1.7 hertz. After applying the forcing function we get two more peaks. The first is at 0.09 hertz, which corresponds to the mode associated with the $k_c$ springs. The second peak is at 0.5 hertz, which is the same frequency as the forcing function.
#
# The reason we see the forcing function is because it is applying a frequency to the system. The motion of the system is affected by this frequency and is then displayed after a fourier transform is done.
#
# The 0.09 hertz peak also presents because the forcing function moves the middle particle. In part 2 with these initial conditions, the middle particle did not move. This was because the force was always zero on it. Since it did not move, the $k_c$ springs did not have a strong response (if any) and did not contribute to the frequency spectrum.
#
# There is an additional normal mode, which corresponds to the forcing function.

# %% [markdown]
# ### Exercise 5.5: three coupled oscillators
#
# 1.  Run the program with $N=3$, $k_{c}=0.2$ and $k=1$ and arbitrary but
#     nonzero initial displacements. Describe the time-dependence of the
#     motion of the particles.
#
# 2.  Consider the following initial conditions:
#     ${u_{1}=u_{2}=u_{3}=0.5}$, ${u_{1}=0.5,u_{2}=-0.5,u_{3}=0.5}$,
#     ${u_{1}=0.5,u_{2}=0,u_{3}=-0.5}$ (all the velocities are
#     initially zero) If these initial conditions correspond to normal
#     modes, determine the normal modes frequencies.
#
# 3.  Add an external driving force to particle 1 and determine the normal
#     mode frequencies. Compare your results with the frequencies you
#     obtained in part 2. How many normal modes are there?

# %% [markdown]
# #-------
#
# #Exercise 5.3

# %%
class particle(object):  ## We recycle our 1D particle object
    
    def __init__(self, mass=1., x=0., v=0.):
        self.mass = mass
        self.f = 0
        self.x= x
        self.v = v
        
    def move(self, dt):
        # Euler-Cromer
        self.v = self.v + self.f/self.mass*dt
        self.x = self.x + self.v*dt
        
class CoupledSystem(object):

    def __init__(self, N, k, kc, dt): 
        self.N = N
        self.dt = dt
        self.k = k
        self.kc = kc
        #self.j = j
        self.particles = [particle()]
        for i in range(1,N):
            self.particles.append(particle()) # we create a list of N particles

    def evolve(self, j):        
        # Compute the interaction forces with the other particles
        for i in range(self.N-1):
            self.particles[i].f = self.kc*(self.particles[i+1].x + self.particles[i-1].x - 2*self.particles[i].x)
        
        w = 2*math.pi*0.1
        #   Added driving force to the line below (u1). Driving Force = 0.5cos(2*pi*0.5*time) where the frequency is 0.5
        self.particles[0].f = self.kc*(self.particles[1].x - self.particles[0].x) - self.k*self.particles[0].x + .5*math.cos(w*dt*j)
        self.particles[N-1].f = self.kc*(self.particles[N-2].x - self.particles[N-1].x) - self.k*self.particles[N-1].x

        for p in self.particles:
            p.move(dt)
            
    def energy(self):
        # Challenge
        return (ke,pe)

# %%
# %matplotlib inline
import numpy as np
import math
from matplotlib import pyplot

N = 3
k = 1.0
kc = 0.2
dt = 0.01
tmax = 150
nsteps = int(tmax/dt)

S = CoupledSystem(N, k, kc, dt)
S.particles[0].x = 0.5
S.particles[1].x = 0.5
S.particles[2].x = 0.5

t = np.linspace(0.,tmax,nsteps)
x_5d3 = np.zeros(shape=(N,nsteps))

for i in range(nsteps):
    for n in range(S.N):
        x_5d3[n,i] = S.particles[n].x
    S.evolve(i)

# %% [markdown]
# #---
#
# Below I have plotted numerous amplitude vs. time plots. They all have the same initial conditions; however, the driving frequency (f) has been increased in increments of 0.05 hz. I start at 0 hz and go to .30 hz. By doing this it can be seen that the steady state amplitude increases. Below is list summarizing the data:
#
#     frequency   Amplitude
#     0           0.9
#     .05         0.9
#     .10         1.0
#     .15         2.2
#     .20         3.2
#     .25         1.2
#     .30         0.8
#
# It can be seen that when the frequency was close to the normal modes found above, that the amplitude increased dramatically. However, what happens when we set the driving force frequency very close to the normal modes? These plots can be seen at the very bottom. It can be seen that the amplitude grows very quickly, and that it appears to grow without bound. This is very important. In the other plots the amplitude can be seen to decrease again; however, when the driving force is very close to the normal mode, the amplitude will appear to increase without bound. If it were exactly equalt to the driving force then it would always increase and never decrease.
#
#     For example, when the driving force is f=.09 then the amplitude is 2.8, which is significantly more than the 1.0 at f = .10.
#
#     Another example is when the driving force is f = 1.7 then the amplitude is 11, which is significantly more than the 2.2 when f = 2.2.
#
# f = 1.7 has a greater effect than f = 0.09 because there are two normal modes around that frequency, so its effect is multiplied.

# %%
pyplot.plot(t, x_5d3[0,], color='green', ls='-', lw=1)

pyplot.xlabel('time (s)')
pyplot.ylabel('x (m)');
pyplot.title('Exercise 5.3: Position vs. Time f=0')

# %%
pyplot.plot(t, x_5d3[0,], color='green', ls='-', lw=1)

pyplot.xlabel('time (s)')
pyplot.ylabel('x (m)');
pyplot.title('Exercise 5.3: Position vs. Time f=.05')

# %%
pyplot.plot(t, x_5d3[0,], color='green', ls='-', lw=1)

pyplot.xlabel('time (s)')
pyplot.ylabel('x (m)');
pyplot.title('Exercise 5.3: Position vs. Time f=.1')

# %%
pyplot.plot(t, x_5d3[0,], color='green', ls='-', lw=1)

pyplot.xlabel('time (s)')
pyplot.ylabel('x (m)');
pyplot.title('Exercise 5.3: Position vs. Time f=.15')

# %%
pyplot.plot(t, x_5d3[0,], color='green', ls='-', lw=1)

pyplot.xlabel('time (s)')
pyplot.ylabel('x (m)');
pyplot.title('Exercise 5.3: Position vs. Time f=.2')

# %%
pyplot.plot(t, x_5d3[0,], color='green', ls='-', lw=1)

pyplot.xlabel('time (s)')
pyplot.ylabel('x (m)');
pyplot.title('Exercise 5.3: Position vs. Time f=.25')

# %%
pyplot.plot(t, x_5d3[0,], color='green', ls='-', lw=1)

pyplot.xlabel('time (s)')
pyplot.ylabel('x (m)');
pyplot.title('Exercise 5.3: Position vs. Time f=.3')

# %% [markdown]
# #---
#
# The plots with the driving force very close to the normal modes can be seen below. Here the amplitude has increased dramatically, and it appears that the amplitude will continue to increase. Below are some comments about the plots:
#
#     For example, when the driving force is f=.09 then the amplitude is 2.8, which is significantly more than the 1.0 at f = .10.
#
#     Another example is when the driving force is f = 1.7 then the amplitude is 11, which is significantly more than the 2.2 when f = 2.2.
#
# f = 1.7 has a greater effect than f = 0.09 because there are two normal modes around that frequency, so its effect is multiplied.

# %%
pyplot.plot(t, x_5d3[0,], color='green', ls='-', lw=1)

pyplot.xlabel('time (s)')
pyplot.ylabel('x (m)');
pyplot.title('Exercise 5.3: Position vs. Time f=.09')

# %%
pyplot.plot(t, x_5d3[0,], color='green', ls='-', lw=1)

pyplot.xlabel('time (s)')
pyplot.ylabel('x (m)');
pyplot.title('Exercise 5.3: Position vs. Time f=.17')

# %% [markdown]
# ### Exercise 5.3: response to an external force
#
# Add an external driving force $F(t)=F_{0}\cos {\omega t}$ to particle 1.
# plot $u_{1}(t)$ and determine its maximum steady state amplitude
# $A(\omega )$ for each value of $\omega $. Confirm that near a resonance
# $A(\omega )$ exhibits a rapid increase with $\omega $, and $u_{1}(t)$
# increases without bound at the resonant frequency. Determine the
# resonant frequencies for the pairs of $k$-values already considered in
# parts 2-4 in Exercise 5.2. How do these values of $\omega $ compare to
# those in the previous exercise?
